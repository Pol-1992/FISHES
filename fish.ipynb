# %%
import requests
import pandas as pd
import time
from datetime import datetime
from calendar import monthrange
from dotenv import load_dotenv
import os
from funciones import *

# %%
load_dotenv()

api_key = os.getenv("API_KEY")

# %%
# 🔐 Token de iNaturalist
TOKEN = os.getenv("API_TOKEN")
headers = {"Authorization": TOKEN}

# %% [markdown]
# **THAILAND**

# %%
#  Coordenadas de Tailandia
zone_thailand = {
    "nelat": 20.4,
    "nelng": 105,
    "swlat": 5.5,
    "swlng": 97
}

# %%
for year in range(2015, 2023):
    print(f"\n📅 Descargando {year}...")
    observations_year = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 47178,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_thailand
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Saltando año {year}, página {page} por errores repetidos")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} finalizado (página {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                observations_year.append({
                    "year": year,
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    # Guardado anual
    pd.DataFrame(observations_year).to_csv(f"peces_thailandia_{year}.csv", index=False)
    print(f"💾 Guardado: peces_thailandia_{year}.csv")
# Out:
# 📅 Descargando 2015...
#    ✅ Página 1 → 100 observaciones
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 44
#      42     print(f"   ✅ Página {page} → {len(data)} observaciones")
#      43     page += 1
# ---> 44     time.sleep(1)
#      46 # Guardado anual
#      47 pd.DataFrame(observations_year).to_csv(f"peces_thailandia_{year}.csv", index=False)
#
# KeyboardInterrupt:

# %%
current_year = datetime.today().year
current_month = datetime.today().month

for year in [2023, 2024, 2025]:
    max_month = 12 if year < current_year else current_month

    for month in range(1, max_month + 1):
        print(f"\n📆 Descargando {year}-{month:02d}...")
        observations_month = []
        page = 1
        days_in_month = monthrange(year, month)[1]
        d1 = f"{year}-{month:02d}-01"
        d2 = f"{year}-{month:02d}-{days_in_month}"

        while True:
            url = "https://api.inaturalist.org/v1/observations"
            params = {
                "taxon_id": 47178,
                "per_page": 100,
                "page": page,
                "order_by": "observed_on",
                "order": "desc",
                "d1": d1,
                "d2": d2,
                **zone_thailand
            }

            response = get_with_retry(url, params, headers)
            if response is None:
                print(f"⛔️ Saltando {year}-{month:02d}, página {page} por errores repetidos")
                break

            data = response.json().get("results", [])
            if not data:
                print(f"✅ Mes {year}-{month:02d} finalizado (página {page - 1})")
                break

            for obs in data:
                coords = obs.get("geojson", {}).get("coordinates", [None, None])
                taxon = obs.get("taxon", {})
                if taxon and coords != [None, None]:
                    observations_month.append({
                        "year": year,
                        "month": month,
                        "date": obs.get("observed_on"),
                        "scientific_name": taxon.get("name"),
                        "common_name": taxon.get("preferred_common_name"),
                        "latitude": coords[1],
                        "longitude": coords[0]
                    })

            print(f"   ✅ Página {page} → {len(data)} observaciones")
            page += 1
            time.sleep(1)

        # Guardado mensual
        pd.DataFrame(observations_month).to_csv(f"peces_thailandia_{year}_{month:02d}.csv", index=False)
        print(f"💾 Guardado: peces_thailandia_{year}_{month:02d}.csv")
# Out:
# 📆 Descargando 2023-01...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 33 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2023-01 finalizado (página 9)
# 💾 Guardado: peces_thailandia_2023_01.csv
#
# 📆 Descargando 2023-02...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 69 observaciones
# ✅ Mes 2023-02 finalizado (página 9)
# 💾 Guardado: peces_thailandia_2023_02.csv
#
# 📆 Descargando 2023-03...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 100 observaciones
#    ✅ Página 16 → 100 observaciones
#    ✅ Página 17 → 13 observaciones
# ✅ Mes 2023-03 finalizado (página 17)
# 💾 Guardado: peces_thailandia_2023_03.csv
#
# 📆 Descargando 2023-04...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 86 observaciones
# ✅ Mes 2023-04 finalizado (página 11)
# 💾 Guardado: peces_thailandia_2023_04.csv
#
# 📆 Descargando 2023-05...
#    ✅ Página 1 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 47 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2023-05 finalizado (página 5)
# 💾 Guardado: peces_thailandia_2023_05.csv
#
# 📆 Descargando 2023-06...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 72 observaciones
# ✅ Mes 2023-06 finalizado (página 5)
# 💾 Guardado: peces_thailandia_2023_06.csv
#
# 📆 Descargando 2023-07...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 56 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2023-07 finalizado (página 12)
# 💾 Guardado: peces_thailandia_2023_07.csv
#
# 📆 Descargando 2023-08...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 28 observaciones
# ✅ Mes 2023-08 finalizado (página 6)
# 💾 Guardado: peces_thailandia_2023_08.csv
#
# 📆 Descargando 2023-09...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 42 observaciones
# ✅ Mes 2023-09 finalizado (página 9)
# 💾 Guardado: peces_thailandia_2023_09.csv
#
# 📆 Descargando 2023-10...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 56 observaciones
# ✅ Mes 2023-10 finalizado (página 10)
# 💾 Guardado: peces_thailandia_2023_10.csv
#
# 📆 Descargando 2023-11...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2023-11 finalizado (página 13)
# 💾 Guardado: peces_thailandia_2023_11.csv
#
# 📆 Descargando 2023-12...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 72 observaciones
# ✅ Mes 2023-12 finalizado (página 14)
# 💾 Guardado: peces_thailandia_2023_12.csv
#
# 📆 Descargando 2024-01...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 3 observaciones
# ✅ Mes 2024-01 finalizado (página 15)
# 💾 Guardado: peces_thailandia_2024_01.csv
#
# 📆 Descargando 2024-02...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 62 observaciones
# ✅ Mes 2024-02 finalizado (página 12)
# 💾 Guardado: peces_thailandia_2024_02.csv
#
# 📆 Descargando 2024-03...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 5 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 9 observaciones
# ✅ Mes 2024-03 finalizado (página 11)
# 💾 Guardado: peces_thailandia_2024_03.csv
#
# 📆 Descargando 2024-04...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 29 observaciones
# ✅ Mes 2024-04 finalizado (página 15)
# 💾 Guardado: peces_thailandia_2024_04.csv
#
# 📆 Descargando 2024-05...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 59 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2024-05 finalizado (página 6)
# 💾 Guardado: peces_thailandia_2024_05.csv
#
# 📆 Descargando 2024-06...
#    ✅ Página 1 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 2 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 3 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 4 → 44 observaciones
# ✅ Mes 2024-06 finalizado (página 4)
# 💾 Guardado: peces_thailandia_2024_06.csv
#
# 📆 Descargando 2024-07...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 15 → 16 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2024-07 finalizado (página 15)
# 💾 Guardado: peces_thailandia_2024_07.csv
#
# 📆 Descargando 2024-08...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 29 observaciones
# ✅ Mes 2024-08 finalizado (página 8)
# 💾 Guardado: peces_thailandia_2024_08.csv
#
# 📆 Descargando 2024-09...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 84 observaciones
# ✅ Mes 2024-09 finalizado (página 5)
# 💾 Guardado: peces_thailandia_2024_09.csv
#
# 📆 Descargando 2024-10...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 39 observaciones
# ✅ Mes 2024-10 finalizado (página 8)
# 💾 Guardado: peces_thailandia_2024_10.csv
#
# 📆 Descargando 2024-11...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 61 observaciones
# ✅ Mes 2024-11 finalizado (página 9)
# 💾 Guardado: peces_thailandia_2024_11.csv
#
# 📆 Descargando 2024-12...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 49 observaciones
# ✅ Mes 2024-12 finalizado (página 7)
# 💾 Guardado: peces_thailandia_2024_12.csv
#
# 📆 Descargando 2025-01...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 54 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Mes 2025-01 finalizado (página 9)
# 💾 Guardado: peces_thailandia_2025_01.csv
#
# 📆 Descargando 2025-02...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 16 → 11 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 2): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⚠️ Conexión fallida (intento 3): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ⛔️ Saltando 2025-02, página 17 por errores repetidos
# 💾 Guardado: peces_thailandia_2025_02.csv
#
# 📆 Descargando 2025-03...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 100 observaciones
#    ✅ Página 16 → 100 observaciones
#    ✅ Página 17 → 100 observaciones
#    ✅ Página 18 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 19 → 100 observaciones
#    ✅ Página 20 → 1 observaciones
# ✅ Mes 2025-03 finalizado (página 20)
# 💾 Guardado: peces_thailandia_2025_03.csv
#
# 📆 Descargando 2025-04...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
#    ✅ Página 8 → 100 observaciones
#    ✅ Página 9 → 100 observaciones
#    ✅ Página 10 → 100 observaciones
#    ✅ Página 11 → 100 observaciones
#    ✅ Página 12 → 100 observaciones
#    ✅ Página 13 → 100 observaciones
#    ✅ Página 14 → 100 observaciones
#    ✅ Página 15 → 100 observaciones
#    ✅ Página 16 → 40 observaciones
# ✅ Mes 2025-04 finalizado (página 16)
# 💾 Guardado: peces_thailandia_2025_04.csv
#
# 📆 Descargando 2025-05...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 100 observaciones
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 8 → 72 observaciones
# ✅ Mes 2025-05 finalizado (página 8)
# 💾 Guardado: peces_thailandia_2025_05.csv
#
# 📆 Descargando 2025-06...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 17 observaciones
# ✅ Mes 2025-06 finalizado (página 2)
# 💾 Guardado: peces_thailandia_2025_06.csv

# %%
years = range(2015, 2026)

#  Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones para Tailandia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 505362,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_thailand
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tiburones_tailandia_{year}.csv", index=False)
    print(f"💾 Guardado: tiburones_tailandia_{year}.csv")
# Out:
# 📅 Descargando observaciones para Tailandia - Año 2015...
#    ✅ Página 1 → 18 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2015.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2016...
#    ✅ Página 1 → 20 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2016.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2017...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 62 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2017.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2018...
#    ✅ Página 1 → 63 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2018.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2019...
#    ✅ Página 1 → 44 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2019.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2020...
#    ✅ Página 1 → 88 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2020.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2021...
#    ✅ Página 1 → 34 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2021.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2022...
#    ✅ Página 1 → 95 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: tiburones_tailandia_2022.csv
#
# 📅 Descargando observaciones para Tailandia - Año 2023...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 22
#      10 url = "https://api.inaturalist.org/v1/observations"
#      11 params = {
#      12     "taxon_id": 505362,
#      13     "per_page": 100,
#    (...)
#      19     **zone_thailand
#      20 }
# ---> 22 response = get_with_retry(url, params, headers)
#      23 if response is None:
#      24     print(f"⛔️ Error persistente en {year}, página {page}")
#
# Cell In[10], line 5, in get_with_retry(url, params, headers, max_retries, delay)
#       3 for attempt in range(1, max_retries + 1):
#       4     try:
# ----> 5         response = requests.get(url, params=params, headers=headers)
#       6         if response.status_code == 200:
#       7             return response
#
# File c:\Users\polur\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\polur\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\polur\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\polur\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\polur\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\polur\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\polur\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\polur\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\polur\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\polur\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\polur\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\polur\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\polur\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\polur\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
years = range(2015, 2026)

# 🔽 Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones de cetáceos para Tailandia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 152871,  # Cetacea
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_thailand
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"cetaceos_tailandia_{year}.csv", index=False)
    print(f"💾 Guardado: cetaceos_tailandia_{year}.csv")
# Out:
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2015...
#    ✅ Página 1 → 4 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2015.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2016...
#    ✅ Página 1 → 2 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2016.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2017...
#    ✅ Página 1 → 8 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2017.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2018...
#    ✅ Página 1 → 19 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2018.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2019...
#    ✅ Página 1 → 13 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2019.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2020...
#    ✅ Página 1 → 24 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2020.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2021...
#    ✅ Página 1 → 19 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2021.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2022...
#    ✅ Página 1 → 24 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2022.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2023...
#    ✅ Página 1 → 42 observaciones
# ✅ Año 2023 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2023.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2024...
#    ✅ Página 1 → 53 observaciones
# ✅ Año 2024 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2024.csv
#
# 📅 Descargando observaciones de cetáceos para Tailandia - Año 2025...
#    ✅ Página 1 → 13 observaciones
# ✅ Año 2025 completado (última página: 1)
# 💾 Guardado: cetaceos_tailandia_2025.csv

# %%
years = range(2015, 2026)

for year in years:
    print(f"\n📅 Descargando observaciones de tortugas marinas para Tailandia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "q": "sea turtle",
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_thailand
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tortugas_tailandia_{year}.csv", index=False)
    print(f"💾 Guardado: tortugas_tailandia_{year}.csv")
# Out:
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2015...
#    ✅ Página 1 → 7 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2015.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2016...
#    ✅ Página 1 → 8 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2016.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2017...
#    ✅ Página 1 → 26 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2017.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2018...
#    ✅ Página 1 → 36 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2018.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2019...
#    ✅ Página 1 → 20 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2019.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2020...
#    ✅ Página 1 → 40 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2020.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2021...
#    ✅ Página 1 → 21 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2021.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2022...
#    ✅ Página 1 → 45 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2022.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2023...
#    ✅ Página 1 → 91 observaciones
# ✅ Año 2023 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2023.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2024...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 12 observaciones
# ✅ Año 2024 completado (última página: 2)
# 💾 Guardado: tortugas_tailandia_2024.csv
#
# 📅 Descargando observaciones de tortugas marinas para Tailandia - Año 2025...
#    ✅ Página 1 → 51 observaciones
# ✅ Año 2025 completado (última página: 1)
# 💾 Guardado: tortugas_tailandia_2025.csv

# %% [markdown]
# **INDONESIA**

# %%
# 🌏 Coordenadas generales de Indonesia
zone_indonesia = {
    "nelat": 5.9,
    "nelng": 141.0,
    "swlat": -11.0,
    "swlng": 95.0
}

# %%
for year in range(2015, 2023):
    print(f"\n📅 Descargando Indonesia - Año {year}...")
    observations_year = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 47178,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Saltando {year}, página {page} por errores repetidos")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} finalizado (página {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                observations_year.append({
                    "year": year,
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    # Guardar el CSV por año
    pd.DataFrame(observations_year).to_csv(f"peces_indonesia_{year}.csv", index=False)
    print(f"💾 Guardado: peces_indonesia_{year}.csv")

# %%
years_to_redo = [2016, 2020]

for year in years_to_redo:
    print(f"\n📅 Descargando Indonesia - Año {year} completo...")
    observations_year = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 47178,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Año {year} detenido en página {page} por error persistente")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                observations_year.append({
                    "year": year,
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    # 💾 Guardar CSV nuevo (sobreescribís si querés)
    pd.DataFrame(observations_year).to_csv(f"peces_indonesia_{year}_completo.csv", index=False)
    print(f"💾 Guardado: peces_indonesia_{year}_completo.csv")

# %%
years = [2019, 2022, 2023, 2024, 2025]

for year in years:
    print(f"\n📅 Año {year} en curso...")
    for month in generate_months1(year):
        start_date = f"{month}-01"
        end_date = f"{month}-28" if month[-2:] == "02" else f"{month}-30"
        if month[-2:] in ["01", "03", "05", "07", "08", "10", "12"]:
            end_date = f"{month}-31"

        all_obs = []
        page = 1
        print(f"🔍 {month}...")

        while True:
            url = "https://api.inaturalist.org/v1/observations"
            params = {
                "taxon_id": 47178,
                "per_page": 100,
                "page": page,
                "order_by": "observed_on",
                "order": "desc",
                "d1": start_date,
                "d2": end_date,
                **zone_indonesia
            }

            response = get_with_retry(url, params, headers)
            if response is None:
                print(f"⛔️ Fallo persistente en {month}, página {page}")
                break

            data = response.json().get("results", [])
            if not data:
                print(f"✅ {month} finalizado")
                break

            for obs in data:
                coords = obs.get("geojson", {}).get("coordinates", [None, None])
                taxon = obs.get("taxon", {})
                if taxon and coords != [None, None]:
                    all_obs.append({
                        "date": obs.get("observed_on"),
                        "scientific_name": taxon.get("name"),
                        "common_name": taxon.get("preferred_common_name"),
                        "latitude": coords[1],
                        "longitude": coords[0]
                    })

            print(f"   ✅ Página {page} → {len(data)} observaciones")
            page += 1
            time.sleep(1)

        # 💾 Guardar CSV por mes
        df_month = pd.DataFrame(all_obs)
        df_month.to_csv(f"peces_indonesia_{month}.csv", index=False)
        print(f"💾 Guardado: peces_indonesia_{month}.csv")

# %%
for month in generate_months(2022, 2025):
    start_date = f"{month}-01"
    end_date = f"{month}-28"
    if month[-2:] in ["01", "03", "05", "07", "08", "10", "12"]:
        end_date = f"{month}-31"
    elif month[-2:] in ["04", "06", "09", "11"]:
        end_date = f"{month}-30"

    print(f"\n🔍 Descargando observaciones de {month}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 47178,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": start_date,
            "d2": end_date,
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Fallo persistente en {month}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ {month} finalizado")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_month = pd.DataFrame(all_obs)
    df_month.to_csv(f"peces_indonesia_{month}.csv", index=False)
    print(f"💾 Guardado: peces_indonesia_{month}.csv")

# %%
years = range(2015, 2026)

#  Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones para Indonesia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 505362,  # Neoselachii (tiburones + rayas)
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tiburones_indonesia_{year}.csv", index=False)
    print(f"💾 Guardado: tiburones_indonesia_{year}.csv")

# %%
years = range(2015, 2026)

# 🔽 Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones de cetáceos para Indonesia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 152871,  # Cetacea
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"cetaceos_indonesia_{year}.csv", index=False)
    print(f"💾 Guardado: cetaceos_indonesia_{year}.csv")
# Out:
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2015...
# ⚠️ Conexión fallida (intento 1): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    ✅ Página 1 → 20 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2015.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2016...
#    ✅ Página 1 → 20 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2016.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2017...
#    ✅ Página 1 → 35 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2017.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2018...
#    ✅ Página 1 → 33 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2018.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2019...
#    ✅ Página 1 → 37 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2019.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2020...
#    ✅ Página 1 → 21 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2020.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2021...
#    ✅ Página 1 → 9 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2021.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2022...
#    ✅ Página 1 → 61 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2022.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2023...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 14 observaciones
# ✅ Año 2023 completado (última página: 2)
# 💾 Guardado: cetaceos_indonesia_2023.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2024...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 30 observaciones
# ✅ Año 2024 completado (última página: 3)
# 💾 Guardado: cetaceos_indonesia_2024.csv
#
# 📅 Descargando observaciones de cetáceos para Indonesia - Año 2025...
#    ✅ Página 1 → 36 observaciones
# ✅ Año 2025 completado (última página: 1)
# 💾 Guardado: cetaceos_indonesia_2025.csv

# %%
years = range(2015, 2026)

for year in years:
    print(f"\n📅 Descargando observaciones de tortugas marinas para Indonesia - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "q": "sea turtle",
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_indonesia
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tortugas_indonesia_{year}.csv", index=False)
    print(f"💾 Guardado: tortugas_indonesia_{year}.csv")
# Out:
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2015...
#    ✅ Página 1 → 71 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: tortugas_indonesia_2015.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2016...
#    ✅ Página 1 → 73 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: tortugas_indonesia_2016.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2017...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 37 observaciones
# ✅ Año 2017 completado (última página: 2)
# 💾 Guardado: tortugas_indonesia_2017.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2018...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 6 observaciones
# ✅ Año 2018 completado (última página: 3)
# 💾 Guardado: tortugas_indonesia_2018.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2019...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 81 observaciones
# ✅ Año 2019 completado (última página: 3)
# 💾 Guardado: tortugas_indonesia_2019.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2020...
#    ✅ Página 1 → 68 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: tortugas_indonesia_2020.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2021...
#    ✅ Página 1 → 61 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: tortugas_indonesia_2021.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2022...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 25 observaciones
# ✅ Año 2022 completado (última página: 3)
# 💾 Guardado: tortugas_indonesia_2022.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2023...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 34 observaciones
# ✅ Año 2023 completado (última página: 6)
# 💾 Guardado: tortugas_indonesia_2023.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2024...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 100 observaciones
#    ✅ Página 4 → 100 observaciones
#    ✅ Página 5 → 100 observaciones
#    ✅ Página 6 → 100 observaciones
#    ✅ Página 7 → 24 observaciones
# ✅ Año 2024 completado (última página: 7)
# 💾 Guardado: tortugas_indonesia_2024.csv
#
# 📅 Descargando observaciones de tortugas marinas para Indonesia - Año 2025...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 28 observaciones
# ✅ Año 2025 completado (última página: 3)
# 💾 Guardado: tortugas_indonesia_2025.csv

# %% [markdown]
# **FILIPINAS**

# %%
# Coordenadas generales de Filipinas
zone_philippines = {
    "nelat": 21.0,   # Norte de Luzón
    "nelng": 127.0,  # Mar de Filipinas
    "swlat": 4.5,    # Sur de Mindanao
    "swlng": 116.0   # Mar de Sulu
}

# %%
years = range(2015, 2022)

# 🔽 Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones para Filipinas - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 47178,
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_philippines
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"peces_filipinas_{year}.csv", index=False)
    print(f"💾 Guardado: peces_filipinas_{year}.csv")

# %%
years = [2022, 2023, 2024, 2025]

for year in years:
    print(f"\n📅 Año {year} en curso...")
    for month in generate_months1(year):
        year_int = int(month[:4])
        month_int = int(month[-2:])
        last_day = monthrange(year_int, month_int)[1]
        
        start_date = f"{month}-01"
        end_date = f"{month}-{last_day}"

        all_obs = []
        page = 1
        print(f"🔍 {month}...")

        while True:
            url = "https://api.inaturalist.org/v1/observations"
            params = {
                "taxon_id": 47178,  # Peces óseos (Actinopterygii)
                "per_page": 100,
                "page": page,
                "order_by": "observed_on",
                "order": "desc",
                "d1": start_date,
                "d2": end_date,
                **zone_philippines
            }

            response = get_with_retry(url, params, headers)
            if response is None:
                print(f"⛔️ Fallo persistente en {month}, página {page}")
                break

            data = response.json().get("results", [])
            if not data:
                print(f"✅ {month} finalizado")
                break

            for obs in data:
                coords = obs.get("geojson", {}).get("coordinates", [None, None])
                taxon = obs.get("taxon", {})
                if taxon and coords != [None, None]:
                    all_obs.append({
                        "date": obs.get("observed_on"),
                        "scientific_name": taxon.get("name"),
                        "common_name": taxon.get("preferred_common_name"),
                        "latitude": coords[1],
                        "longitude": coords[0]
                    })

            print(f"   ✅ Página {page} → {len(data)} observaciones")
            page += 1
            time.sleep(1)

        # 💾 Guardar CSV por mes
        df_month = pd.DataFrame(all_obs)
        df_month.to_csv(f"peces_filipinas_{month}.csv", index=False)
        print(f"💾 Guardado: peces_filipinas_{month}.csv")

# %%
years = range(2015, 2026)

# Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones para Filipinas - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 505362,  # Neoselachii = tiburones + rayas
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_philippines
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tiburones_filipinas_{year}.csv", index=False)
    print(f"💾 Guardado: tiburones_filipinas_{year}.csv")

# %%
years = range(2015, 2026)

#  Descarga por año
for year in years:
    print(f"\n📅 Descargando observaciones de cetáceos para Filipinas - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "taxon_id": 152871,  # Cetacea
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_philippines
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"cetaceos_filipinas_{year}.csv", index=False)
    print(f"💾 Guardado: cetaceos_filipinas_{year}.csv")
# Out:
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2015...
#    ✅ Página 1 → 2 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2015.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2016...
#    ✅ Página 1 → 8 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2016.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2017...
#    ✅ Página 1 → 2 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2017.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2018...
#    ✅ Página 1 → 7 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2018.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2019...
#    ✅ Página 1 → 4 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2019.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2020...
#    ✅ Página 1 → 6 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2020.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2021...
# ✅ Año 2021 completado (última página: 0)
# 💾 Guardado: cetaceos_filipinas_2021.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2022...
#    ✅ Página 1 → 9 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2022.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2023...
#    ✅ Página 1 → 7 observaciones
# ✅ Año 2023 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2023.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2024...
#    ✅ Página 1 → 10 observaciones
# ✅ Año 2024 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2024.csv
#
# 📅 Descargando observaciones de cetáceos para Filipinas - Año 2025...
#    ✅ Página 1 → 6 observaciones
# ✅ Año 2025 completado (última página: 1)
# 💾 Guardado: cetaceos_filipinas_2025.csv

# %%
for year in years:
    print(f"\n📅 Descargando observaciones de tortugas marinas para Filipinas - Año {year}...")
    all_obs = []
    page = 1

    while True:
        url = "https://api.inaturalist.org/v1/observations"
        params = {
            "q": "sea turtle",  # búsqueda textual
            "per_page": 100,
            "page": page,
            "order_by": "observed_on",
            "order": "desc",
            "d1": f"{year}-01-01",
            "d2": f"{year}-12-31",
            **zone_philippines
        }

        response = get_with_retry(url, params, headers)
        if response is None:
            print(f"⛔️ Error persistente en {year}, página {page}")
            break

        data = response.json().get("results", [])
        if not data:
            print(f"✅ Año {year} completado (última página: {page - 1})")
            break

        for obs in data:
            coords = obs.get("geojson", {}).get("coordinates", [None, None])
            taxon = obs.get("taxon", {})
            if taxon and coords != [None, None]:
                all_obs.append({
                    "date": obs.get("observed_on"),
                    "scientific_name": taxon.get("name"),
                    "common_name": taxon.get("preferred_common_name"),
                    "latitude": coords[1],
                    "longitude": coords[0]
                })

        print(f"   ✅ Página {page} → {len(data)} observaciones")
        page += 1
        time.sleep(1)

    df_year = pd.DataFrame(all_obs)
    df_year.to_csv(f"tortugas_filipinas_{year}.csv", index=False)
    print(f"💾 Guardado: tortugas_filipinas_{year}.csv")
# Out:
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2015...
#    ✅ Página 1 → 27 observaciones
# ✅ Año 2015 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2015.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2016...
#    ✅ Página 1 → 53 observaciones
# ✅ Año 2016 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2016.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2017...
#    ✅ Página 1 → 73 observaciones
# ✅ Año 2017 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2017.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2018...
#    ✅ Página 1 → 70 observaciones
# ✅ Año 2018 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2018.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2019...
#    ✅ Página 1 → 98 observaciones
# ✅ Año 2019 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2019.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2020...
#    ✅ Página 1 → 51 observaciones
# ✅ Año 2020 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2020.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2021...
#    ✅ Página 1 → 19 observaciones
# ✅ Año 2021 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2021.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2022...
#    ✅ Página 1 → 78 observaciones
# ✅ Año 2022 completado (última página: 1)
# 💾 Guardado: tortugas_filipinas_2022.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2023...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 30 observaciones
# ✅ Año 2023 completado (última página: 2)
# 💾 Guardado: tortugas_filipinas_2023.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2024...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 100 observaciones
#    ✅ Página 3 → 16 observaciones
# ✅ Año 2024 completado (última página: 3)
# 💾 Guardado: tortugas_filipinas_2024.csv
#
# 📅 Descargando observaciones de tortugas marinas para Filipinas - Año 2025...
#    ✅ Página 1 → 100 observaciones
#    ✅ Página 2 → 3 observaciones
# ✅ Año 2025 completado (última página: 2)
# 💾 Guardado: tortugas_filipinas_2025.csv

# %% [markdown]
# **CONCATENAR**

# %%
anuales = [f"peces_thailandia_{año}.csv" for año in range(2015, 2023)]

# Generar los nombres de archivos por mes (2023-2025_06)
mensuales = []
for año in range(2023, 2026):
    max_mes = 12
    if año == 2025:
        max_mes = 6
    for mes in range(1, max_mes + 1):
        mensuales.append(f"peces_thailandia_{año}_{mes:02d}.csv")

# Unir las dos listas
archivos = anuales + mensuales

# Leer todos los archivos y concatenarlos
df_thailandia = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)

# Guardar el resultado
df_thailandia.to_csv("peces_thailandia_total.csv", index=False)

# %%
anuales = [f"peces_filipinas_{año}.csv" for año in range(2015, 2022)]

# Archivos mensuales (2022–2025 hasta junio)
mensuales = []
for año in range(2022, 2026):
    max_mes = 12
    if año == 2025:
        max_mes = 6
    for mes in range(1, max_mes + 1):
        mensuales.append(f"peces_filipinas_{año}-{mes:02d}.csv")

# Unir listas
archivos = anuales + mensuales

# Leer y concatenar
df_filipinas = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)

# Guardar el resultado
df_filipinas.to_csv("peces_filipinas_total.csv", index=False)

# %%
anuales = [f"peces_indonesia_{año}.csv" for año in [2015, 2017, 2018, 2021]]

# Archivos especiales
especiales = ["peces_indonesia_2016_completo.csv", "peces_indonesia_2020_completo.csv"]

# Archivos mensuales
mensuales = []
for año in [2019, 2022, 2023, 2024, 2025]:
    max_mes = 12
    if año == 2025:
        max_mes = 6
    for mes in range(1, max_mes + 1):
        mensuales.append(f"peces_indonesia_{año}-{mes:02d}.csv")

# Unir todo y concatenar
archivos = anuales + especiales + mensuales
df_indonesia = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)

# Guardar el resultado
df_indonesia.to_csv("peces_indonesia_total.csv", index=False)

# %%
años = range(2015, 2026)
archivos_tailandia = [f"tiburones_tailandia_{año}.csv" for año in años]

df_tailandia = pd.concat([
    pd.read_csv(f) for f in archivos_tailandia if pd.io.common.file_exists(f)
], ignore_index=True)

df_tailandia.to_csv("tiburones_tailandia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_indonesia = [f"tiburones_indonesia_{año}.csv" for año in años]

df_indonesia = pd.concat([
    pd.read_csv(f) for f in archivos_indonesia if pd.io.common.file_exists(f)
], ignore_index=True)

df_indonesia.to_csv("tiburones_indonesia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_filipinas = [f"tiburones_filipinas_{año}.csv" for año in años]

df_filipinas = pd.concat([
    pd.read_csv(f) for f in archivos_filipinas if pd.io.common.file_exists(f)
], ignore_index=True)

df_filipinas.to_csv("tiburones_filipinas_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_cetaceos_tailandia = [f"cetaceos_tailandia_{año}.csv" for año in años]

df_cetaceos_tailandia = pd.concat([
    pd.read_csv(f) for f in archivos_cetaceos_tailandia if pd.io.common.file_exists(f)
], ignore_index=True)

df_cetaceos_tailandia.to_csv("cetaceos_tailandia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_cetaceos_indonesia = [f"cetaceos_indonesia_{año}.csv" for año in años]

df_cetaceos_indonesia = pd.concat([
    pd.read_csv(f) for f in archivos_cetaceos_indonesia if pd.io.common.file_exists(f)
], ignore_index=True)

df_cetaceos_indonesia.to_csv("cetaceos_indonesia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_cetaceos_filipinas = [f"cetaceos_filipinas_{año}.csv" for año in años]

df_cetaceos_filipinas = pd.concat([
    pd.read_csv(f) for f in archivos_cetaceos_filipinas if pd.io.common.file_exists(f)
], ignore_index=True)

df_cetaceos_filipinas.to_csv("cetaceos_filipinas_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_tortugas_tailandia = [f"tortugas_tailandia_{año}.csv" for año in años]

df_tortugas_tailandia = pd.concat([
    pd.read_csv(f) for f in archivos_tortugas_tailandia if pd.io.common.file_exists(f)
], ignore_index=True)

df_tortugas_tailandia.to_csv("tortugas_tailandia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_tortugas_indonesia = [f"tortugas_indonesia_{año}.csv" for año in años]

df_tortugas_indonesia = pd.concat([
    pd.read_csv(f) for f in archivos_tortugas_indonesia if pd.io.common.file_exists(f)
], ignore_index=True)

df_tortugas_indonesia.to_csv("tortugas_indonesia_2015_2025.csv", index=False)

# %%
años = range(2015, 2026)
archivos_tortugas_filipinas = [f"tortugas_filipinas_{año}.csv" for año in años]

df_tortugas_filipinas = pd.concat([
    pd.read_csv(f) for f in archivos_tortugas_filipinas if pd.io.common.file_exists(f)
], ignore_index=True)

df_tortugas_filipinas.to_csv("tortugas_filipinas_2015_2025.csv", index=False)

# %%
df_peces = pd.read_csv("peces_thailandia_total.csv")
df_cetaceos = pd.read_csv("cetaceos_tailandia_2015_2025.csv")
df_tiburones = pd.read_csv("tiburones_tailandia_2015_2025.csv")
df_tortugas = pd.read_csv("tortugas_tailandia_2015_2025.csv")

df_animales_tailandia = pd.concat([
    df_peces, df_cetaceos, df_tiburones, df_tortugas
], ignore_index=True)

df_animales_tailandia.to_csv("animales_marinos_tailandia_2015_2025.csv", index=False)

# %%
df_peces = pd.read_csv("peces_indonesia_total.csv")
df_cetaceos = pd.read_csv("cetaceos_indonesia_2015_2025.csv")
df_tiburones = pd.read_csv("tiburones_indonesia_2015_2025.csv")
df_tortugas = pd.read_csv("tortugas_indonesia_2015_2025.csv")

df_animales_indonesia = pd.concat([
    df_peces, df_cetaceos, df_tiburones, df_tortugas
], ignore_index=True)

df_animales_indonesia.to_csv("animales_marinos_indonesia_2015_2025.csv", index=False)

# %%
df_peces = pd.read_csv("peces_filipinas_total.csv")
df_cetaceos = pd.read_csv("cetaceos_filipinas_2015_2025.csv")
df_tiburones = pd.read_csv("tiburones_filipinas_2015_2025.csv")
df_tortugas = pd.read_csv("tortugas_filipinas_2015_2025.csv")

df_animales_filipinas = pd.concat([
    df_peces, df_cetaceos, df_tiburones, df_tortugas
], ignore_index=True)

df_animales_filipinas.to_csv("animales_marinos_filipinas_2015_2025.csv", index=False)
